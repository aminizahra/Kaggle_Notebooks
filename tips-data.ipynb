# %% [markdown]
# <a href="https://www.kaggle.com/aminizahra/tips-data?scriptVersionId=88418692" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **Context**
#
# One waiter recorded information about each tip he received over a period of a few months working in one restaurant. In all he recorded 244 tips.
#
#
# **Acknowledgements**
#
# The data was reported in a collection of case studies for business statistics.
#
# Bryant, P. G. and Smith, M (1995) Practical Data Analysis: Case Studies in Business Statistics. Homewood, IL: Richard D. Irwin Publishing
#
# The dataset is also available through the Python package Seaborn.
#
# **Hint:**
# Of course, this database has additional columns compared to other  tips datasets.

# %% [markdown]
# **Dataset info**
#
# RangeIndex: 244 entries, 0 to 243
#
# Data columns (total 11 columns):
#
#      Column                    Non-Null Count  Dtype
#
# ---  ------                    --------------  -----
#
#  0   total_bill                                        244 non-null    float64
#
#  1   tip                                                  244 non-null    float64
#
#  2   sex                                               244 non-null    object
#
#  3   smoker                                        244 non-null    object
#
#  4   day                                               244 non-null    object
#
#  5   time                                              244 non-null    object
#
#  6   size                                              244 non-null    int64
#
#  7   price_per_person                        244 non-null    float64
#
#  8   Payer Name                                244 non-null    object
#
#  9   CC Number                                 244 non-null    int64
#
#  10  Payment ID                                244 non-null    object
#
# dtypes: float64(3), int64(2), object(6)
#
# **Some details**
# total_bill
# a numeric vector, the bill amount (dollars)
#
# tip
# a numeric vector, the tip amount (dollars)
#
# sex
# a factor with levels Female Male, gender of the payer of the bill
#
# Smoker
# a factor with levels No Yes, whether the party included smokers
#
# day
# a factor with levels Friday Saturday Sunday Thursday, day of the week
#
# time
# a factor with levels Day Night, rough time of day
#
# size
# a numeric vector, number of people in party

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Reading Dataset

# %%
df=pd.read_csv('../input/tips-dataset/tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %% [markdown]
# # Data overview

# %%
# This command displays the first 5 rows by default.

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# If you need more rows, specify their number in the command.
# For example 10 rows

df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# 5          Erik Smith   213140353657882    Sun9679
# 6  Kristopher Johnson  2223727524230344    Sun5985
# 7         Robert Buck  3514785077705092    Sun8157
# 8     Joseph Mcdonald  3522866365840377    Sun6820
# 9       Jerome Abbott  3532124519049786    Sun3775

# %%
# Pandas .size, .shape and .ndim are used to 
# return size, shape and dimensions of data frames and series.

df.shape
# Out:
# (244, 11)

# %%
# Pandas dataframe.info() function is used to get a concise summary of the dataframe. 
# It comes really handy when doing exploratory analysis of the data. 
# To get a quick overview of the dataset we use the dataframe.info() function.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
# Pandas DataFrame.columns attribute return the column labels of the given Dataframe.

df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
# Pandas tail() method is used to return bottom n (5 by default) rows of a data frame or series.

df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
# Pandas describe() is used to view some basic statistical details like 
# percentile, mean, std etc. of a data frame or a series of numeric values.

df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# ## Selecting & Indexing

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
# type() method returns class type of the argument(object) passed as parameter
# . type() function is mostly used for debugging purposes.

type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
type(df[['total_bill', 'tip']])
# Out:
# pandas.core.frame.DataFrame

# %%
# A column is added to the data set named tip_percentage and the information is placed inside it.

df['tip_percentage']= 100*(df['tip']/df['total_bill'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
# The numpy.round_() is a mathematical function that rounds an array to the given number of decimals.

df['tip_percentage']=np.round(df['tip_percentage'], decimals=3)

# %%
df['tip_percentage']
# Out:
# 0       5.945
# 1      16.054
# 2      16.659
# 3      13.978
# 4      14.681
#         ...
# 239    20.393
# 240     7.358
# 241     8.822
# 242     9.820
# 243    15.974
# Name: tip_percentage, Length: 244, dtype: float64

# %%
np.round(df['tip_percentage'], 2)
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 239    20.39
# 240     7.36
# 241     8.82
# 242     9.82
# 243    15.97
# Name: tip_percentage, Length: 244, dtype: float64

# %%
# Pandas provide data analysts a way to delete and filter data frame using .drop() 
# method. Rows can be removed using index label or column name using this method.

df.drop('tip_percentage', axis=1)

# A DataFrame object has two axes: “axis 0” and “axis 1”.
# “axis 0” represents rows and “axis 1” represents columns.
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df=df.drop('tip_percentage', axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# Pandas set_index() is a method to set a List, Series or Data frame as index of a Data Frame.

df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# ...                      ...                 ...               ...
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
# Thur672                 9.39     Michelle Hardin  3511451626698139
#
# [244 rows x 10 columns]

# %%
# Pandas provide a unique method to retrieve rows from a Data frame. 
# Dataframe.iloc[] method is used when the index label of a data frame is something other than 
# numeric series of 0, 1, 2, 3….n or in case the user doesn’t know the index label. 
# Rows can be extracted using an imaginary index position which isn’t visible in the data frame.

df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 0, dtype: object

# %%
df.iloc[2:4]
# Out:
#    total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 2       21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31  Male     No  Sun  Dinner     2             11.84
#
#          Payer Name         CC Number Payment ID
# 2    Travis Walters  6011812112971322    Sun4458
# 3  Nathaniel Harris  4676137647685994    Sun5260

# %%
# Pandas reset_index() is a method to reset index of a Data Frame. reset_index() method sets 
# a list of integer ranging from 0 to length of data as index.

df=df.reset_index()

# %%
df.head()
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number Payment ID
# 0              8.49  Christy Cunningham  3560325168603410    Sun2959
# 1              3.45      Douglas Tucker  4478071379779230    Sun4608
# 2              7.00      Travis Walters  6011812112971322    Sun4458
# 3             11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4              6.15        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ## Conditional Selection

# %%
df[df['total_bill']> 30]
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 11      11       35.26   5.00  Female     No   Sun  Dinner     4
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 39      39       31.27   5.00    Male     No   Sat  Dinner     3
# 44      44       30.40   5.60    Male     No   Sun  Dinner     4
# 47      47       32.40   6.00    Male     No   Sun  Dinner     4
# 52      52       34.81   5.20  Female     No   Sun  Dinner     4
# 56      56       38.01   3.00    Male    Yes   Sat  Dinner     4
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 83      83       32.68   5.00    Male    Yes  Thur   Lunch     2
# 85      85       34.83   5.17  Female     No  Thur   Lunch     4
# 95      95       40.17   4.73    Male    Yes   Fri  Dinner     4
# 102    102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 112    112       38.07   4.00    Male     No   Sun  Dinner     3
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 142    142       41.19   5.00    Male     No  Thur   Lunch     5
# 156    156       48.17   5.00    Male     No   Sun  Dinner     6
# 167    167       31.71   4.50    Male     No   Sun  Dinner     4
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 173    173       31.85   3.18    Male    Yes   Sun  Dinner     2
# 175    175       32.90   3.11    Male    Yes   Sun  Dinner     2
# 179    179       34.63   3.55    Male    Yes   Sun  Dinner     2
# 180    180       34.65   3.68    Male    Yes   Sun  Dinner     4
# 182    182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184    184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 187    187       30.46   2.00    Male    Yes   Sun  Dinner     5
# 197    197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 207    207       38.73   3.00    Male    Yes   Sat  Dinner     4
# 210    210       30.06   2.00    Male    Yes   Sat  Dinner     3
# 212    212       48.33   9.00    Male     No   Sat  Dinner     4
# 219    219       30.14   3.09  Female    Yes   Sat  Dinner     4
# 237    237       32.83   1.17    Male    Yes   Sat  Dinner     2
# 238    238       35.83   4.67  Female     No   Sat  Dinner     3
#
#      price_per_person             Payer Name         CC Number Payment ID
# 11               8.82           Diane Macias  4577817359320969    Sun6686
# 23               9.86         Lance Peterson  3542584061609808     Sat239
# 39              10.42      Mr. Brandon Berry  6011525851069856    Sat6373
# 44               7.60            Todd Cooper      503846761263    Sun2274
# 47               8.10           James Barnes  3552002592874186    Sun9677
# 52               8.70           Emily Daniel  4291280793094374    Sun6165
# 56               9.50  James Christensen DDS   349793629453226    Sat8903
# 59              12.07            Brian Ortiz  6596453823950595    Sat8139
# 83              16.34          Daniel Murphy  5356177501009133   Thur8801
# 85               8.71            Shawna Cook  6011787464177340   Thur7972
# 95              10.04          Aaron Bentley   180026611638690    Fri9628
# 102             14.77          Heather Cohen   379771118886604    Sat6240
# 112             12.69             Jeff Lopez  3572865915176463     Sun591
# 141              5.72         Steven Carlson  3526515703718508   Thur1025
# 142              8.24           Eric Andrews  4356531761046453   Thur3621
# 156              8.03          Ryan Gonzales  3523151482063321    Sun7518
# 167              7.93         Michael Lawson  3566285921227119    Sun3719
# 170             16.94          Gregory Clark  5473850968388236    Sat1954
# 173             15.92            Scott Perez  3577115550328507    Sun9335
# 175             16.45        Nathan Reynolds   370307040837149    Sun5109
# 179             17.32           Brian Bailey   346656312114848    Sun9851
# 180              8.66       James Hebert DDS      676168737648    Sun7544
# 182             15.12           Jose Parsons  4112207559459910    Sun2337
# 184             20.27            Stephen Cox  3547798222044029    Sun5140
# 187              6.09          David Barrett  4792882899700988    Sun9987
# 197             10.78            Brooke Soto  5544902205760175   Thur9313
# 207              9.68          Ricky Ramirez   347817964484033    Sat4505
# 210             10.02          Shawn Mendoza    30184049218122    Sat8361
# 212             12.08        Alex Williamson      676218815212    Sat4590
# 219              7.54           Shelby House      502097403252    Sat8863
# 237             16.42           Thomas Brown  4284722681265508    Sat2929
# 238             11.94         Kimberly Crane      676184013727    Sat9777

# %%
df[df['total_bill']> 30].shape
# Out:
# (32, 12)

# %%
df[df['sex']=='Male']
# Out:
#      index  total_bill   tip   sex smoker  day    time  size  \
# 1        1       10.34  1.66  Male     No  Sun  Dinner     3
# 2        2       21.01  3.50  Male     No  Sun  Dinner     3
# 3        3       23.68  3.31  Male     No  Sun  Dinner     2
# 5        5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        6        8.77  2.00  Male     No  Sun  Dinner     2
# ..     ...         ...   ...   ...    ...  ...     ...   ...
# 236    236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237    237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239    239       29.03  5.92  Male     No  Sat  Dinner     3
# 241    241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75  Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 1                3.45      Douglas Tucker  4478071379779230    Sun4608
# 2                7.00      Travis Walters  6011812112971322    Sun4458
# 3               11.84    Nathaniel Harris  4676137647685994    Sun5260
# 5                6.32          Erik Smith   213140353657882    Sun9679
# 6                4.38  Kristopher Johnson  2223727524230344    Sun5985
# ..                ...                 ...               ...        ...
# 236              6.30       Matthew Myers  3543676378973965    Sat5032
# 237             16.42        Thomas Brown  4284722681265508    Sat2929
# 239              9.68       Michael Avila  5296068606052842    Sat2657
# 241             11.34          Keith Wong  6011891618747196    Sat3880
# 242              8.91        Dennis Dixon     4375220550950      Sat17
#
# [157 rows x 12 columns]

# %%
df[df['sex']=='Male'].shape
# Out:
# (157, 12)

# %%
# & --> and
df[(df['sex']=='Male') & (df['total_bill']> 30)]
# Out:
#      index  total_bill    tip   sex smoker   day    time  size  \
# 23      23       39.42   7.58  Male     No   Sat  Dinner     4
# 39      39       31.27   5.00  Male     No   Sat  Dinner     3
# 44      44       30.40   5.60  Male     No   Sun  Dinner     4
# 47      47       32.40   6.00  Male     No   Sun  Dinner     4
# 56      56       38.01   3.00  Male    Yes   Sat  Dinner     4
# 59      59       48.27   6.73  Male     No   Sat  Dinner     4
# 83      83       32.68   5.00  Male    Yes  Thur   Lunch     2
# 95      95       40.17   4.73  Male    Yes   Fri  Dinner     4
# 112    112       38.07   4.00  Male     No   Sun  Dinner     3
# 141    141       34.30   6.70  Male     No  Thur   Lunch     6
# 142    142       41.19   5.00  Male     No  Thur   Lunch     5
# 156    156       48.17   5.00  Male     No   Sun  Dinner     6
# 167    167       31.71   4.50  Male     No   Sun  Dinner     4
# 170    170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 173    173       31.85   3.18  Male    Yes   Sun  Dinner     2
# 175    175       32.90   3.11  Male    Yes   Sun  Dinner     2
# 179    179       34.63   3.55  Male    Yes   Sun  Dinner     2
# 180    180       34.65   3.68  Male    Yes   Sun  Dinner     4
# 182    182       45.35   3.50  Male    Yes   Sun  Dinner     3
# 184    184       40.55   3.00  Male    Yes   Sun  Dinner     2
# 187    187       30.46   2.00  Male    Yes   Sun  Dinner     5
# 207    207       38.73   3.00  Male    Yes   Sat  Dinner     4
# 210    210       30.06   2.00  Male    Yes   Sat  Dinner     3
# 212    212       48.33   9.00  Male     No   Sat  Dinner     4
# 237    237       32.83   1.17  Male    Yes   Sat  Dinner     2
#
#      price_per_person             Payer Name         CC Number Payment ID
# 23               9.86         Lance Peterson  3542584061609808     Sat239
# 39              10.42      Mr. Brandon Berry  6011525851069856    Sat6373
# 44               7.60            Todd Cooper      503846761263    Sun2274
# 47               8.10           James Barnes  3552002592874186    Sun9677
# 56               9.50  James Christensen DDS   349793629453226    Sat8903
# 59              12.07            Brian Ortiz  6596453823950595    Sat8139
# 83              16.34          Daniel Murphy  5356177501009133   Thur8801
# 95              10.04          Aaron Bentley   180026611638690    Fri9628
# 112             12.69             Jeff Lopez  3572865915176463     Sun591
# 141              5.72         Steven Carlson  3526515703718508   Thur1025
# 142              8.24           Eric Andrews  4356531761046453   Thur3621
# 156              8.03          Ryan Gonzales  3523151482063321    Sun7518
# 167              7.93         Michael Lawson  3566285921227119    Sun3719
# 170             16.94          Gregory Clark  5473850968388236    Sat1954
# 173             15.92            Scott Perez  3577115550328507    Sun9335
# 175             16.45        Nathan Reynolds   370307040837149    Sun5109
# 179             17.32           Brian Bailey   346656312114848    Sun9851
# 180              8.66       James Hebert DDS      676168737648    Sun7544
# 182             15.12           Jose Parsons  4112207559459910    Sun2337
# 184             20.27            Stephen Cox  3547798222044029    Sun5140
# 187              6.09          David Barrett  4792882899700988    Sun9987
# 207              9.68          Ricky Ramirez   347817964484033    Sat4505
# 210             10.02          Shawn Mendoza    30184049218122    Sat8361
# 212             12.08        Alex Williamson      676218815212    Sat4590
# 237             16.42           Thomas Brown  4284722681265508    Sat2929

# %%
df[(df['sex']=='Male') & (df['total_bill']> 30)].shape
# Out:
# (25, 12)

# %%
# | --> or

df[(df['sex']=='Male') | (df['total_bill']> 30)]
# Out:
#      index  total_bill   tip     sex smoker  day    time  size  \
# 1        1       10.34  1.66    Male     No  Sun  Dinner     3
# 2        2       21.01  3.50    Male     No  Sun  Dinner     3
# 3        3       23.68  3.31    Male     No  Sun  Dinner     2
# 5        5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        6        8.77  2.00    Male     No  Sun  Dinner     2
# ..     ...         ...   ...     ...    ...  ...     ...   ...
# 237    237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238    238       35.83  4.67  Female     No  Sat  Dinner     3
# 239    239       29.03  5.92    Male     No  Sat  Dinner     3
# 241    241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 1                3.45      Douglas Tucker  4478071379779230    Sun4608
# 2                7.00      Travis Walters  6011812112971322    Sun4458
# 3               11.84    Nathaniel Harris  4676137647685994    Sun5260
# 5                6.32          Erik Smith   213140353657882    Sun9679
# 6                4.38  Kristopher Johnson  2223727524230344    Sun5985
# ..                ...                 ...               ...        ...
# 237             16.42        Thomas Brown  4284722681265508    Sat2929
# 238             11.94      Kimberly Crane      676184013727    Sat9777
# 239              9.68       Michael Avila  5296068606052842    Sat2657
# 241             11.34          Keith Wong  6011891618747196    Sat3880
# 242              8.91        Dennis Dixon     4375220550950      Sat17
#
# [164 rows x 12 columns]

# %%
df[(df['day']=='Sat') | (df['day']=='Sun')]
# Out:
#      index  total_bill   tip     sex smoker  day    time  size  \
# 0        0       16.99  1.01  Female     No  Sun  Dinner     2
# 1        1       10.34  1.66    Male     No  Sun  Dinner     3
# 2        2       21.01  3.50    Male     No  Sun  Dinner     3
# 3        3       23.68  3.31    Male     No  Sun  Dinner     2
# 4        4       24.59  3.61  Female     No  Sun  Dinner     4
# ..     ...         ...   ...     ...    ...  ...     ...   ...
# 238    238       35.83  4.67  Female     No  Sat  Dinner     3
# 239    239       29.03  5.92    Male     No  Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# 1                3.45      Douglas Tucker  4478071379779230    Sun4608
# 2                7.00      Travis Walters  6011812112971322    Sun4458
# 3               11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4                6.15        Tonya Carter  4832732618637221    Sun2251
# ..                ...                 ...               ...        ...
# 238             11.94      Kimberly Crane      676184013727    Sat9777
# 239              9.68       Michael Avila  5296068606052842    Sat2657
# 240             13.59      Monica Sanders  3506806155565404    Sat1766
# 241             11.34          Keith Wong  6011891618747196    Sat3880
# 242              8.91        Dennis Dixon     4375220550950      Sat17
#
# [163 rows x 12 columns]

# %%
# Pandas isin() method is used to filter data frames. isin() method helps in selecting rows 
# with having a particular(or Multiple) value in a particular column.

df[df['day'].isin(['Sat', 'Sun'])]
# Out:
#      index  total_bill   tip     sex smoker  day    time  size  \
# 0        0       16.99  1.01  Female     No  Sun  Dinner     2
# 1        1       10.34  1.66    Male     No  Sun  Dinner     3
# 2        2       21.01  3.50    Male     No  Sun  Dinner     3
# 3        3       23.68  3.31    Male     No  Sun  Dinner     2
# 4        4       24.59  3.61  Female     No  Sun  Dinner     4
# ..     ...         ...   ...     ...    ...  ...     ...   ...
# 238    238       35.83  4.67  Female     No  Sat  Dinner     3
# 239    239       29.03  5.92    Male     No  Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# 1                3.45      Douglas Tucker  4478071379779230    Sun4608
# 2                7.00      Travis Walters  6011812112971322    Sun4458
# 3               11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4                6.15        Tonya Carter  4832732618637221    Sun2251
# ..                ...                 ...               ...        ...
# 238             11.94      Kimberly Crane      676184013727    Sat9777
# 239              9.68       Michael Avila  5296068606052842    Sat2657
# 240             13.59      Monica Sanders  3506806155565404    Sat1766
# 241             11.34          Keith Wong  6011891618747196    Sat3880
# 242              8.91        Dennis Dixon     4375220550950      Sat17
#
# [163 rows x 12 columns]

# %% [markdown]
# ## Useful Methods

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             244 non-null    int64
#  1   total_bill        244 non-null    float64
#  2   tip               244 non-null    float64
#  3   sex               244 non-null    object
#  4   smoker            244 non-null    object
#  5   day               244 non-null    object
#  6   time              244 non-null    object
#  7   size              244 non-null    int64
#  8   price_per_person  244 non-null    float64
#  9   Payer Name        244 non-null    object
#  10  CC Number         244 non-null    int64
#  11  Payment ID        244 non-null    object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 23.0+ KB

# %%
def last_four(num):
    return str(num)[-4:]

# %%
Num=1234567890
print("Last 4 number of ",Num," is: ",last_four(Num))
# Out:
# Last 4 number of  1234567890  is:  7890

# %%
df['total_bill'].apply(lambda bill: 0.2*bill)
# Out:
# 0      3.398
# 1      2.068
# 2      4.202
# 3      4.736
# 4      4.918
#        ...
# 239    5.806
# 240    5.436
# 241    4.534
# 242    3.564
# 243    3.756
# Name: total_bill, Length: 244, dtype: float64

# %%
df['total_bill_20']=df['total_bill'].apply(lambda bill: 0.2*bill)

# %%
df.head()
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number Payment ID  \
# 0              8.49  Christy Cunningham  3560325168603410    Sun2959
# 1              3.45      Douglas Tucker  4478071379779230    Sun4608
# 2              7.00      Travis Walters  6011812112971322    Sun4458
# 3             11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4              6.15        Tonya Carter  4832732618637221    Sun2251
#
#    total_bill_20
# 0          3.398
# 1          2.068
# 2          4.202
# 3          4.736
# 4          4.918

# %%
df.sort_values('tip')
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 67      67        3.07   1.00  Female    Yes   Sat  Dinner     1
# 236    236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92      92        5.75   1.00  Female    Yes   Fri  Dinner     2
# 111    111        7.25   1.00  Female     No   Sat  Dinner     1
# 0        0       16.99   1.01  Female     No   Sun  Dinner     2
# ..     ...         ...    ...     ...    ...   ...     ...   ...
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 212    212       48.33   9.00    Male     No   Sat  Dinner     4
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
#      price_per_person          Payer Name         CC Number Payment ID  \
# 67               3.07       Tiffany Brock  4359488526995267    Sat3455
# 236              6.30       Matthew Myers  3543676378973965    Sat5032
# 92               2.88        Leah Ramirez  3508911676966392    Fri3780
# 111              7.25         Terri Jones  3559221007826887    Sat4801
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# ..                ...                 ...               ...        ...
# 141              5.72      Steven Carlson  3526515703718508   Thur1025
# 59              12.07         Brian Ortiz  6596453823950595    Sat8139
# 23               9.86      Lance Peterson  3542584061609808     Sat239
# 212             12.08     Alex Williamson      676218815212    Sat4590
# 170             16.94       Gregory Clark  5473850968388236    Sat1954
#
#      total_bill_20
# 67           0.614
# 236          2.520
# 92           1.150
# 111          1.450
# 0            3.398
# ..             ...
# 141          6.860
# 59           9.654
# 23           7.884
# 212          9.666
# 170         10.162
#
# [244 rows x 13 columns]

# %%
df.sort_values('tip', ascending=False)
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212    212       48.33   9.00    Male     No   Sat  Dinner     4
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# ..     ...         ...    ...     ...    ...   ...     ...   ...
# 0        0       16.99   1.01  Female     No   Sun  Dinner     2
# 236    236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 111    111        7.25   1.00  Female     No   Sat  Dinner     1
# 67      67        3.07   1.00  Female    Yes   Sat  Dinner     1
# 92      92        5.75   1.00  Female    Yes   Fri  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID  \
# 170             16.94       Gregory Clark  5473850968388236    Sat1954
# 212             12.08     Alex Williamson      676218815212    Sat4590
# 23               9.86      Lance Peterson  3542584061609808     Sat239
# 59              12.07         Brian Ortiz  6596453823950595    Sat8139
# 141              5.72      Steven Carlson  3526515703718508   Thur1025
# ..                ...                 ...               ...        ...
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# 236              6.30       Matthew Myers  3543676378973965    Sat5032
# 111              7.25         Terri Jones  3559221007826887    Sat4801
# 67               3.07       Tiffany Brock  4359488526995267    Sat3455
# 92               2.88        Leah Ramirez  3508911676966392    Fri3780
#
#      total_bill_20
# 170         10.162
# 212          9.666
# 23           7.884
# 59           9.654
# 141          6.860
# ..             ...
# 0            3.398
# 236          2.520
# 111          1.450
# 67           0.614
# 92           1.150
#
# [244 rows x 13 columns]

# %%
df.sort_values(['tip', 'size'])
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 67      67        3.07   1.00  Female    Yes   Sat  Dinner     1
# 111    111        7.25   1.00  Female     No   Sat  Dinner     1
# 92      92        5.75   1.00  Female    Yes   Fri  Dinner     2
# 236    236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 0        0       16.99   1.01  Female     No   Sun  Dinner     2
# ..     ...         ...    ...     ...    ...   ...     ...   ...
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 212    212       48.33   9.00    Male     No   Sat  Dinner     4
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
#      price_per_person          Payer Name         CC Number Payment ID  \
# 67               3.07       Tiffany Brock  4359488526995267    Sat3455
# 111              7.25         Terri Jones  3559221007826887    Sat4801
# 92               2.88        Leah Ramirez  3508911676966392    Fri3780
# 236              6.30       Matthew Myers  3543676378973965    Sat5032
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# ..                ...                 ...               ...        ...
# 141              5.72      Steven Carlson  3526515703718508   Thur1025
# 59              12.07         Brian Ortiz  6596453823950595    Sat8139
# 23               9.86      Lance Peterson  3542584061609808     Sat239
# 212             12.08     Alex Williamson      676218815212    Sat4590
# 170             16.94       Gregory Clark  5473850968388236    Sat1954
#
#      total_bill_20
# 67           0.614
# 111          1.450
# 92           1.150
# 236          2.520
# 0            3.398
# ..             ...
# 141          6.860
# 59           9.654
# 23           7.884
# 212          9.666
# 170         10.162
#
# [244 rows x 13 columns]

# %%
df.corr()
# Out:
#                      index  total_bill       tip      size  price_per_person  \
# index             1.000000    0.044526 -0.026709  0.008061          0.042043
# total_bill        0.044526    1.000000  0.675734  0.598315          0.647554
# tip              -0.026709    0.675734  1.000000  0.489299          0.347405
# size              0.008061    0.598315  0.489299  1.000000         -0.175359
# price_per_person  0.042043    0.647554  0.347405 -0.175359          1.000000
# CC Number        -0.117043    0.104576  0.110857 -0.030239          0.135240
# total_bill_20     0.044526    1.000000  0.675734  0.598315          0.647554
#
#                   CC Number  total_bill_20
# index             -0.117043       0.044526
# total_bill         0.104576       1.000000
# tip                0.110857       0.675734
# size              -0.030239       0.598315
# price_per_person   0.135240       0.647554
# CC Number          1.000000       0.104576
# total_bill_20      0.104576       1.000000

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
# Pandas dataframe.idxmax() function returns index of first occurrence of maximum over requested axis.
# While finding the index of the maximum value across any index, all NA/null values are excluded.

df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# index                            170
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# total_bill_20                 10.162
# Name: 170, dtype: object

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.head()
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number Payment ID  \
# 0              8.49  Christy Cunningham  3560325168603410    Sun2959
# 1              3.45      Douglas Tucker  4478071379779230    Sun4608
# 2              7.00      Travis Walters  6011812112971322    Sun4458
# 3             11.84    Nathaniel Harris  4676137647685994    Sun5260
# 4              6.15        Tonya Carter  4832732618637221    Sun2251
#
#    total_bill_20
# 0          3.398
# 1          2.068
# 2          4.202
# 3          4.736
# 4          4.918

# %%
# Pandas Series.value_counts() function return a Series containing counts of unique values. 
# The resulting object will be in descending order so that the first element is the most 
# frequently-occurring element. Excludes NA values by default.

df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
# While analyzing the data, many times the user wants to see the unique values in a particular column, 
# which can be done using Pandas unique() function.

df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %%
df.groupby('sex').mean()
# Out:
#              index  total_bill       tip      size  price_per_person  \
# sex
# Female  128.080460   18.056897  2.833448  2.459770          7.464368
# Male    117.853503   20.744076  3.089618  2.630573          8.123057
#
#            CC Number  total_bill_20
# sex
# Female  2.450499e+15       3.611379
# Male    2.626112e+15       4.148815
